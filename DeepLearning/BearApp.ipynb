# %% [markdown]
# <a href="https://colab.research.google.com/github/steimel60/ML/blob/main/DeepLearning/BearApp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#hide but install
# !pip install voila -q
# !jupyter serverextension enable voila --sys-prefix
# !pip install fastbook -q
# Out:
# Enabling: voila
# - Writing config: /usr/etc/jupyter
#     - Validating...
#       voila  OK

# %% [markdown]
# To run app visit:
# [BearApp](https://mybinder.org/v2/gh/steimel60/ML/blob/main/DeepLearning/HEAD?labpath=https%3A%2F%2Fgithub.com%2Fsteimel60%2FML%2Fblob%2Fmain%2FDeepLearning%2FBearApp.ipynb)

# %%
import fastbook
fastbook.setup_book()
from fastbook import *
from fastai.vision.widgets import *
#Load model
path = Path()
learn_inf = load_learner(path/'bear_cnn.pkl')
#Upload image button
btn_upload = widgets.FileUpload()
#Do Work Button
btn_run = widgets.Button(description="Classify")
#Display the image
out_pl = widgets.Output()
#Display prediction
lbl_pred = widgets.Label()
#Click function
def on_click_classify(change):
  img = PILImage.create(btn_upload.data[-1])
  out_pl.clear_output()
  with out_pl: display(img.to_thumb(128,128))
  pred,pred_idx,probs = learn_inf.predict(img)
  lbl_pred.value = f"Prediction: {pred};  Probability: {probs[pred_idx]:.04f}"
#Bind button to func
btn_run.on_click(on_click_classify)
#Build GUI
VBox([widgets.Label('Select your bear!'),
      btn_upload, btn_run, out_pl, lbl_pred])
